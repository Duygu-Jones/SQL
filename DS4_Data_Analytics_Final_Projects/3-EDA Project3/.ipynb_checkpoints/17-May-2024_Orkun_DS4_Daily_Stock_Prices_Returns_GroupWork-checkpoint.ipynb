# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:100%;font-family:Verdana;text-align:center;display:fill;border-radius:15px;background-color:dodgerblue;letter-spacing:1px;overflow:hidden"><b> DAILY STOCK DATASET</b></div>
#
# <p style="text-align: center"><font color='Magenta'> <b>DS-4</b><font color='black'><p>
#
# <p style="text-align: center;"><font color='dodgerblue'> <b>Data Analytics Final Project  | May 2024</b><font color='orange'><p>

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <h3 align="left"><font color=dodgerblue> 🎯 Project Description:</font></h3>
#
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Daily Stock Prices Dataset and Daily Stock Returns Dataset.
# - we will visualize stock prices using Seaborn and Matplotlib.
# - 4 Stocks are considered including JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL).
#
# <h3 align="left"><font color=dodgerblue> 📝 About the Datasets </font></h3>
#
# **Dataset Descriptions:** 'stocks_daily_prices.csv' / 'stocks_daily_returns.csv'
#
# - **Content:** Daily stock prices for various companies.
# - **Rows:** 3642
# - **Columns:** 5
#     - **Date:** Date of the recorded stock price and returns.
#     - **AAPL**: Daily return for Apple Inc.
#     - **JPM**: Daily return for JPMorgan Chase & Co.
#     - **PG**: Daily return for Procter & Gamble Co.
#     - **UAL**: Daily return for United Airlines Holdings, Inc.
#
# - **Purpose:** These datasets Provide a comprehensive view of stock price movements over time for analysis of trends, patterns, and correlations.
#
#
# <h3 align="left"><font color=dodgerblue> ✅All Tasks </font></h3>
#
# - Using the **'stocks_daily_prices.csv' / 'stocks_daily_returns.csv'** included in the course package, write a python script to perform the following tasks:
#
#      **Understanding Data**
# 1. Import both datasets using Pandas.
# 2. Perform basic Exploratory Data Analysis (EDA) on the data
#
#      **Data Visualization**
# 3. Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
# 4. Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
# 5. Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).
# 6. Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.
# 7. Using Seaborn, plot a similar scatterplot between Apple and JP Morgan daily returns.
# 8. Using Matplotlib, plot a pie chart that shows asset allocations, using the 'explode' attribute to increase the separation between AAPL and the rest of the portfolio.
# 9. Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.
#
# 10. Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and standard deviation for both stocks on top of the figure.
#
#      **Correlation and Relationships**
#
# 11. Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.
#
#      **Trends, Patterns, and Anomalies**
# 12. Plot a 3D plot showing all daily returns from JPM, AAPL, and UAL.
#
#      **Conclusions and Insights**
# 13. Her grafik altında, yukarıdaki görselleştirmelerden ve analizlerden elde edilen ana bulgular ve içgörüler özetlenebilir

# %% [markdown]
# ## <font color=#2865c8> <b> UNDERSTANDING THE DATA </b><font color='orange'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> Import The Libraries</b><font color='orange'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Import the “kyphosis.csv" file using Pandas
df_prices = pd.read_csv('stocks_daily_prices.csv')
df_returns = pd.read_csv('stocks_daily_returns.csv')

# %% [markdown]
# ### <font color='dodgerblue'> <b> Perform Basic Statistical Data Analysis </b><font color='orange'>

# %% [markdown]
# <h3 align="left"><font color=dodgerblue> ✅Tasks-1 </font></h3>
#
# - **Check out the head of the dataframe**
# - **Check out the tail of the dataframe**
# - **Check out the info of the dataframe**
# - **Check out the basic statistics of the dataframe**
# - **Check out the duplicated values of the dataframe**
# - **Check out the Missing values of the dataframe**

# %%
df_returns['Date'] = pd.to_datetime(df_returns['Date'])
df_prices['Date'] = pd.to_datetime(df_prices['Date'])

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   datetime64[ns]
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 142.4 KB

# %%
df_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   datetime64[ns]
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 142.4 KB

# %%
df_prices.head()
# Out:
#         Date      AAPL        JPM         PG        UAL
# 0 2008-01-02  5.949703  29.448614  47.058838  29.915234
# 1 2008-01-03  5.952452  29.246094  47.058838  29.690800
# 2 2008-01-04  5.498071  28.582682  46.870098  31.000002
# 3 2008-01-07  5.424478  28.868999  47.175980  29.180000
# 4 2008-01-08  5.229351  27.723747  47.299629  24.389999

# %%
df_returns.head()
# Out:
#         Date      AAPL       JPM        PG        UAL
# 0 2008-01-02  0.000000  0.000000  0.000000   0.000000
# 1 2008-01-03  0.046203 -0.687708  0.000000  -0.750233
# 2 2008-01-04 -7.633517 -2.268378 -0.401072   4.409454
# 3 2008-01-07 -1.338518  1.001718  0.652615  -5.870973
# 4 2008-01-08 -3.597157 -3.967066  0.262103 -16.415356

# %%
df_prices.tail()
# Out:
#            Date        AAPL         JPM          PG        UAL
# 3637 2022-06-13  131.880005  115.989998  138.149994  37.020000
# 3638 2022-06-14  132.759995  114.059998  133.839996  36.990002
# 3639 2022-06-15  135.429993  115.410004  132.509995  37.889999
# 3640 2022-06-16  130.059998  113.430000  133.320007  34.779999
# 3641 2022-06-17  131.559998  113.029999  132.360001  36.279999

# %%
df_returns.tail()
# Out:
#            Date      AAPL       JPM        PG        UAL
# 3637 2022-06-13 -3.828484 -2.977838 -2.677001 -10.058308
# 3638 2022-06-14  0.667265 -1.663937 -3.119796  -0.081034
# 3639 2022-06-15  2.011147  1.183593 -0.993725   2.433084
# 3640 2022-06-16 -3.965145 -1.715625  0.611284  -8.207972
# 3641 2022-06-17  1.153314 -0.352642 -0.720077   4.312824

# %%
df_prices.describe().T
# Out:
#        count                           mean                  min  \
# Date    3642  2015-03-26 07:31:31.927512576  2008-01-02 00:00:00
# AAPL  3642.0                      39.648625             2.387943
# JPM   3642.0                      64.927239            11.545819
# PG    3642.0                      73.729653            29.637867
# UAL   3642.0                      43.183288                 3.13
#
#                       25%                  50%                  75%  \
# Date  2011-08-11 06:00:00  2015-03-26 12:00:00  2018-11-04 06:00:00
# AAPL            11.441511            23.470343            45.398705
# JPM             31.298827            49.601177            95.376392
# PG              46.483078            65.661438            82.645994
# UAL                 22.32            43.080002               60.425
#
#                       max        std
# Date  2022-06-17 00:00:00        NaN
# AAPL           181.511704  43.326924
# JPM            169.500061  39.662998
# PG             163.410004  32.623908
# UAL             96.699997  24.392486

# %%
df_returns.describe().T
# Out:
#        count                           mean                  min  \
# Date    3642  2015-03-26 07:31:31.927512576  2008-01-02 00:00:00
# AAPL  3642.0                        0.10518           -17.919513
# JPM   3642.0                       0.069331           -20.727418
# PG    3642.0                       0.035579            -8.737353
# UAL   3642.0                       0.098866           -36.770882
#
#                       25%                  50%                  75%  \
# Date  2011-08-11 06:00:00  2015-03-26 12:00:00  2018-11-04 06:00:00
# AAPL            -0.797108             0.099403             1.129585
# JPM             -0.889705             0.017241             1.002644
# PG              -0.482903             0.037285             0.595436
# UAL             -1.553845             0.016636             1.636975
#
#                       max       std
# Date  2022-06-17 00:00:00       NaN
# AAPL             13.90495    2.0035
# JPM             25.096737  2.559122
# PG              12.009046  1.198977
# UAL             68.537079  4.361402

# %%
df_prices.duplicated().sum()
# Out:
# 0

# %%
df_returns.duplicated().sum()
# Out:
# 0

# %%
df_prices.isnull().sum()
# Out:
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
df_returns.isnull().sum()
# Out:
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
df_prices.set_index('Date', inplace=True)
df_returns.set_index('Date',inplace=True)

# %% [markdown]
# ##  <font color=#2865c8> <b> DATA VISUALIZATION </b><font color='black'>

# %% [markdown]
# <h3 align="left"><font color=dodgerblue> ✅Tasks-2 </font></h3>
#
# 3. Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
# 4. Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
# 5. Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).
# 6. Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.
# 7. Using Seaborn, plot a similar scatterplot between Apple and JP Morgan daily returns.
#
# 8. Using Matplotlib, plot a pie chart that shows asset allocations, using the 'explode' attribute to increase the separation between AAPL and the rest of the portfolio.
#
# 9. Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.
#
# 10. Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and standard deviation for both stocks on top of the figure.

# %%
# Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
import pandas as pd
import matplotlib.pyplot as plt

# Reload the data
prices_df = pd.read_csv('stocks_daily_prices.csv')
prices_df['Date'] = pd.to_datetime(prices_df['Date'])
prices_df.set_index('Date', inplace=True)

# Plot the time series of stock prices on a single figure
plt.figure(figsize=(14, 7))
for column in prices_df.columns:
    plt.plot(prices_df.index, prices_df[column], label=column)
plt.title('Stock Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Using Matplotlib, plot 4 stocks daily prices on multiple subplots.

# Create subplots for each stock's daily prices
fig, axs = plt.subplots(4, 1, figsize=(14, 14), sharex=True)

# Plot each stock's daily prices in separate subplots
for i, column in enumerate(prices_df.columns):
    axs[i].plot(prices_df.index, prices_df[column], label=column)
    axs[i].set_title(f'{column} Daily Prices')
    axs[i].set_ylabel('Price')
    axs[i].legend()
    axs[i].grid(True)

# Set the xlabel for the last subplot
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# 4. Using Matplotlib, plot 4 stocks daily prices on multiple subplots.

# Create a figure and a set of subplots
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(14, 14), sharex=True)

# 1.yol: Plot each stock's daily price on separate subplots

# AAPL
ax[0].plot(df_prices.index, df_prices['AAPL'], label='AAPL')
ax[0].set_title('Daily Prices of AAPL')
ax[0].set_ylabel('Price')
ax[0].legend()
ax[0].grid(True)

# JPM
ax[1].plot(df_prices.index, df_prices['JPM'], label='JPM')
ax[1].set_title('Daily Prices of JPM')
ax[1].set_ylabel('Price')
ax[1].legend()
ax[1].grid(True)

# PG
ax[2].plot(df_prices.index, df_prices['PG'], label='PG')
ax[2].set_title('Daily Prices of PG')
ax[2].set_ylabel('Price')
ax[2].legend()
ax[2].grid(True)

# UAL
ax[3].plot(df_prices.index, df_prices['UAL'], label='UAL')
ax[3].set_title('Daily Prices of UAL')
ax[3].set_ylabel('Price')
ax[3].legend()
ax[3].grid(True)

#2.yol: Plot each stock's daily price on separate subplots
# for i, column in enumerate(df_prices.columns):
#     axes[i].plot(df_prices.index, df_prices[column], label=column)
#     axes[i].set_title(f'Daily Prices of {column}')
#     axes[i].set_ylabel('Price')
#     axes[i].legend()
#     axes[i].grid(True)
# Add a common x-axis label

plt.xlabel('Date')
# Adjust layout
plt.tight_layout()
# Show plot
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).

# Create subplots for each stock's daily prices in a single row
fig, axs = plt.subplots(1, 4, figsize=(20, 5), sharey=True)

# Plot each stock's daily prices in separate subplots
for i, column in enumerate(prices_df.columns):
    axs[i].plot(prices_df.index, prices_df[column], label=column)
    axs[i].set_title(f'{column} Daily Prices')
    axs[i].set_xlabel('Date')
    axs[i].legend()
    axs[i].grid(True)

# Set the ylabel for the first subplot
axs[0].set_ylabel('Price')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.

import pandas as pd
import matplotlib.pyplot as plt

# Veri setini yeniden yükleyelim
returns_df = pd.read_csv('stocks_daily_returns.csv')
returns_df['Date'] = pd.to_datetime(returns_df['Date'])
returns_df.set_index('Date', inplace=True)

# Scatter plot for daily returns between Apple and JP Morgan
plt.figure(figsize=(10, 6))
plt.scatter(returns_df['AAPL'], returns_df['JPM'], c='blue', alpha=0.5, label='Apple')
plt.scatter(returns_df['JPM'], returns_df['AAPL'], c='brown', alpha=0.5, label='JP Morgan')
plt.title('Scatterplot of Daily Returns: Apple vs. JP Morgan')
plt.xlabel('Apple Daily Returns')
plt.ylabel('JP Morgan Daily Returns')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Veri setini yeniden yükleyelim
returns_df = pd.read_csv('stocks_daily_returns.csv')
returns_df['Date'] = pd.to_datetime(returns_df['Date'])
returns_df.set_index('Date', inplace=True)

# Create a DataFrame for plotting with plotly
plot_df = returns_df.reset_index()

# Add formatted date column for hover data
plot_df['Formatted Date'] = plot_df['Date'].dt.strftime('%Y-%m-%d')

# Create the figure
fig = go.Figure()

# Add Apple scatter plot
fig.add_trace(go.Scatter(
    x=plot_df['AAPL'],
    y=plot_df['JPM'],
    mode='markers',
    marker=dict(color='blue', size=5),
    text=plot_df['Formatted Date'],
    name='Apple',
    hovertemplate='Date: %{text}<br>Apple Returns: %{x}<br>'
))

# Add JP Morgan scatter plot
fig.add_trace(go.Scatter(
    x=plot_df['JPM'],
    y=plot_df['AAPL'],
    mode='markers',
    marker=dict(color='saddlebrown', size=5),
    text=plot_df['Formatted Date'],
    name='JP Morgan',
    hovertemplate='Date: %{text}<br>JP Morgan Returns: %{x}<br>'
))

# Set the titles and labels
fig.update_layout(
    title='Scatterplot of Daily Returns: Apple vs. JP Morgan',
    xaxis_title='Apple Daily Returns',
    yaxis_title='JP Morgan Daily Returns',
    hovermode='closest'
)

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      13 plot_df['Formatted Date'] = plot_df['Date'].dt.strftime('%Y-%m-%d')
#      15 # Create the figure
# ---> 16 fig = go.Figure()
#      18 # Add Apple scatter plot
#      19 fig.add_trace(go.Scatter(
#      20     x=plot_df['AAPL'],
#      21     y=plot_df['JPM'],
#    (...)
#      26     hovertemplate='Date: %{text}<br>Apple Returns: %{x}<br>'
#      27 ))
#
# NameError: name 'go' is not defined

# %%
# Using Matplotlib, plot a pie chart that shows asset allocations, using the 'explode' attribute to increase the separation between AAPL and the rest of the portfolio.

# Define the asset allocations
allocations = [40, 25, 20, 15]  # Example percentages for AAPL, JPM, PG, UAL
labels = ['AAPL', 'JPM', 'PG', 'UAL']

# Define the explode parameter to separate AAPL from the rest
explode = [0.1, 0, 0, 0]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(allocations, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Asset Allocations')
plt.show()

# %%
# Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.

# Define the new asset allocations
allocations = [70, 10, 10, 10]  # New percentages for AAPL, JPM, PG, UAL
labels = ['AAPL', 'JPM', 'PG', 'UAL']

# Define the explode parameter to separate AAPL from the rest
explode = [0.1, 0, 0, 0]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(allocations, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('New Asset Allocations')
plt.show()

# %%
# Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and standard deviation for both stocks on top of the figure.

# Calculate the mean and standard deviation for UAL and PG returns
ual_mean = returns_df['UAL'].mean()
ual_std = returns_df['UAL'].std()
pg_mean = returns_df['PG'].mean()
pg_std = returns_df['PG'].std()

# Plot the histograms for UAL and PG returns
plt.figure(figsize=(14, 7))

# Histogram for UAL
plt.subplot(1, 2, 1)
plt.hist(returns_df['UAL'], bins=40, color='red', alpha=0.7)
plt.title(f'UAL Returns\nMean: {ual_mean:.2f}, Std: {ual_std:.2f}')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)

# Histogram for PG
plt.subplot(1, 2, 2)
plt.hist(returns_df['PG'], bins=40, color='red', alpha=0.7)
plt.title(f'PG Returns\nMean: {pg_mean:.2f}, Std: {pg_std:.2f}')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Volatilite Karşılaştırması: UAL hisse senedi getirileri, PG hisse senedine kıyasla daha yüksek volatiliteye sahiptir. Bu, UAL hisse senedinin PG'ye göre daha riskli olduğunu ve daha büyük fiyat dalgalanmaları yaşadığını göstermektedir.
# Risk ve Getiri: Yatırımcılar, yüksek getiri potansiyeli nedeniyle UAL'ı tercih edebilirler, ancak bu yüksek volatilite aynı zamanda yüksek risk anlamına da gelir. PG hisse senedi ise daha istikrarlı getiriler sunar ve daha düşük risk taşır.
# Portföy Çeşitlendirme: Yatırımcılar, bu bilgileri kullanarak portföylerini çeşitlendirebilir ve risk-getiri dengesini optimize edebilirler.

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <h4 align="left"><font color=dodgerblue> 💡 Output: Scatterplot for Mean Area vs Mean Smoothness:</font></h4>
#
# This scaltter plot..........

# %% [markdown]
# ##  <font color=#2865c8> <b> CORRELATIONS AND RELATIONSHIPS </b><font color='black'>

# %% [markdown]
# <h3 align="left"><font color=dodgerblue> ✅Tasks-3 </font></h3>
#
# 11. Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix for stock returns
corr_matrix = returns_df.corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Correlation Matrix of Stock Daily Returns')
plt.show()

# %% [markdown]
# UAL and PG Correlation: The correlation coefficient between UAL and PG is approximately 0.24, indicating a weak positive relationship.
#
# Diversification: This low correlation suggests that UAL and PG respond differently to market conditions, making them suitable for diversification.
#
# General Observations: The heatmap shows varying correlations among other stocks, such as a higher positive correlation between AAPL and JPM (0.44).
#
# ------------------
#
# UAL ve PG Korelasyonu: UAL ve PG arasındaki korelasyon katsayısı yaklaşık 0.24'tür ve bu, zayıf bir pozitif ilişkiyi gösterir.
#
# Çeşitlendirme: Bu düşük korelasyon, UAL ve PG'nin piyasa koşullarına farklı tepkiler verdiğini, bu nedenle çeşitlendirme için uygun olduklarını gösterir.
#
# Genel Gözlemler: Isı haritası, diğer hisse senetleri arasında değişen korelasyonlar gösterir; örneğin, AAPL ve JPM arasında daha yüksek bir pozitif korelasyon (0.44) vardır.

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <h4 align="left"><font color=dodgerblue> 💡 Output: Scatterplot for Mean Area vs Mean Smoothness:</font></h4>
#
# This scaltter plot..........

# %% [markdown]
# ##  <font color=#2865c8> <b> TRENDS, PATTERNS and ANOMALIES </b><font color='black'>

# %% [markdown]
# <h3 align="left"><font color=dodgerblue> ✅Tasks-4 </font></h3>
#
# 12. Plot a 3D plot showing all daily returns from JPM, AAPL, and UAL.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D plot for daily returns of JPM, AAPL, and UAL
fig = plt.figure(figsize=(16, 16))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for JPM, AAPL, and UAL daily returns
ax.scatter(returns_df['JPM'], returns_df['AAPL'], returns_df['UAL'], c='b', marker='o')

# Set labels for axes
ax.set_xlabel('JPM Daily Returns')
ax.set_ylabel('AAPL Daily Returns')
ax.set_zlabel('UAL Daily Returns')
ax.set_title('3D Plot of Daily Returns: JPM, AAPL, and UAL')

plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go

# Veri setini yeniden yükleyelim
returns_df = pd.read_csv('stocks_daily_returns.csv')
returns_df['Date'] = pd.to_datetime(returns_df['Date'])
returns_df.set_index('Date', inplace=True)

# Create a DataFrame for plotting with plotly
plot_df = returns_df.reset_index()

# Create the figure
fig = go.Figure()

# Add JPM scatter plot
fig.add_trace(go.Scatter3d(
    x=plot_df['Date'],
    y=plot_df['JPM'],
    z=plot_df['UAL'],
    mode='markers',
    marker=dict(color='blue', size=5),
    text=plot_df['Date'].dt.strftime('%Y-%m-%d'),
    name='JPM'
))

# Add AAPL scatter plot
fig.add_trace(go.Scatter3d(
    x=plot_df['Date'],
    y=plot_df['AAPL'],
    z=plot_df['UAL'],
    mode='markers',
    marker=dict(color='red', size=5),
    text=plot_df['Date'].dt.strftime('%Y-%m-%d'),
    name='AAPL'
))

# Add UAL scatter plot
fig.add_trace(go.Scatter3d(
    x=plot_df['Date'],
    y=plot_df['AAPL'],
    z=plot_df['JPM'],
    mode='markers',
    marker=dict(color='green', size=5),
    text=plot_df['Date'].dt.strftime('%Y-%m-%d'),
    name='UAL'
))

# Set the titles and labels
fig.update_layout(
    title='3D Plot of Daily Returns: JPM, AAPL, and UAL',
    scene=dict(
        xaxis_title='Date',
        yaxis_title='Daily Returns',
        zaxis_title='Daily Returns'
    )
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="dfc9ea1e-6e37-4ec0-a5ea-816c7f053909" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfc9ea1e-6e37-4ec0-a5ea-816c7f053909")) {                    Plotly.newPlot(                        "dfc9ea1e-6e37-4ec0-a5ea-816c7f053909",                        [{"marker":{"color":"blue","size":5},"mode":"markers","name":"JPM","text":["2008-01-02","2008-01-03","2008-01-04","2008-01-07","2008-01-08","2008-01-09","2008-01-10","2008-01-11","2008-01-14","2008-01-15","2008-01-16","2008-01-17","2008-01-18","2008-01-22","2008-01-23","2008-01-24","2008-01-25","2008-01-28","2008-01-29","2008-01-30","2008-01-31","2008-02-01","2008-02-04","2008-02-05","2008-02-06","2008-02-07","2008-02-08","2008-02-11","2008-02-12","2008-02-13","2008-02-14","2008-02-15","2008-02-19","2008-02-20","2008-02-21","2008-02-22","2008-02-25","2008-02-26","2008-02-27","2008-02-28","2008-02-29","2008-03-03","2008-03-04","2008-03-05","2008-03-06","2008-03-07","2008-03-10","2008-03-11","2008-03-12","2008-03-13","2008-03-14","2008-03-17","2008-03-18","2008-03-19","2008-03-20","2008-03-24","2008-03-25","2008-03-26","2008-03-27","2008-03-28","2008-03-31","2008-04-01","2008-04-02","2008-04-03","2008-04-04","2008-04-07","2008-04-08","2008-04-09","2008-04-10","2008-04-11","2008-04-14","2008-04-15","2008-04-16","2008-04-17","2008-04-18","2008-04-21","2008-04-22","2008-04-23","2008-04-24","2008-04-25","2008-04-28","2008-04-29","2008-04-30","2008-05-01","2008-05-02","2008-05-05","2008-05-06","2008-05-07","2008-05-08","2008-05-09","2008-05-12","2008-05-13","2008-05-14","2008-05-15","2008-05-16","2008-05-19","2008-05-20","2008-05-21","2008-05-22","2008-05-23","2008-05-27","2008-05-28","2008-05-29","2008-05-30","2008-06-02","2008-06-03","2008-06-04","2008-06-05","2008-06-06","2008-06-09","2008-06-10","2008-06-11","2008-06-12","2008-06-13","2008-06-16","2008-06-17","2008-06-18","2008-06-19","2008-06-20","2008-06-23","2008-06-24","2008-06-25","2008-06-26","2008-06-27","2008-06-30","2008-07-01","2008-07-02","2008-07-03","2008-07-07","2008-07-08","2008-07-09","2008-07-10","2008-07-11","2008-07-14","2008-07-15","2008-07-16","2008-07-17","2008-07-18","2008-07-21","2008-07-22","2008-07-23","2008-07-24","2008-07-25","2008-07-28","2008-07-29","2008-07-30","2008-07-31","2008-08-01","2008-08-04","2008-08-05","2008-08-06","2008-08-07","2008-08-08","2008-08-11","2008-08-12","2008-08-13","2008-08-14","2008-08-15","2008-08-18","2008-08-19","2008-08-20","2008-08-21","2008-08-22","2008-08-25","2008-08-26","2008-08-27","2008-08-28","2008-08-29","2008-09-02","2008-09-03","2008-09-04","2008-09-05","2008-09-08","2008-09-09","2008-09-10","2008-09-11","2008-09-12","2008-09-15","2008-09-16","2008-09-17","2008-09-18","2008-09-19","2008-09-22","2008-09-23","2008-09-24","2008-09-25","2008-09-26","2008-09-29","2008-09-30","2008-10-01","2008-10-02","2008-10-03","2008-10-06","2008-10-07","2008-10-08","2008-10-09","2008-10-10","2008-10-13","2008-10-14","2008-10-15","2008-10-16","2008-10-17","2008-10-20","2008-10-21","2008-10-22","2008-10-23","2008-10-24","2008-10-27","2008-10-28","2008-10-29","2008-10-30","2008-10-31","2008-11-03","2008-11-04","2008-11-05","2008-11-06","2008-11-07","2008-11-10","2008-11-11","2008-11-12","2008-11-13","2008-11-14","2008-11-17","2008-11-18","2008-11-19","2008-11-20","2008-11-21","2008-11-24","2008-11-25","2008-11-26","2008-11-28","2008-12-01","2008-12-02","2008-12-03","2008-12-04","2008-12-05","2008-12-08","2008-12-09","2008-12-10","2008-12-11","2008-12-12","2008-12-15","2008-12-16","2008-12-17","2008-12-18","2008-12-19","2008-12-22","2008-12-23","2008-12-24","2008-12-26","2008-12-29","2008-12-30","2008-12-31","2009-01-02","2009-01-05","2009-01-06","2009-01-07","2009-01-08","2009-01-09","2009-01-12","2009-01-13","2 ...

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <h4 align="left"><font color=dodgerblue> 💡 Output: Scatterplot for Mean Area vs Mean Smoothness:</font></h4>
#
# This scaltter plot..........
